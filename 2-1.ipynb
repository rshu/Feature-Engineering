# %%
import pandas as pd

listen_count = pd.read_csv('./dataset/train_triplets.txt.zip', header=None, delimiter='\t')

# %%
# user, song, listen count
listen_count.sample(n=10, random_state=1)
# Out:
#                                                  0                   1  2
# 20860597  6151509c99d22614f2ffb97693234d8c068b3b22  SORANFA12AB018D06C  1
# 36775876  ba64179e9db0088015c553b1b57510a649bc7a39  SOAPLUS12AF729FB97  2
# 7010689   f8e5fb9b7bfc3a49d38b954e0f32965ef3eee721  SOBPLGR12A6D4F82BE  5
# 39440471  1e4f12a501a751c51c10dc110015a20133aa85cf  SOWTYVO12AB0180BDA  1
# 4735031   5c543dc5cca959864248c6ed01dd551446803b9a  SORCKPU12AB0183117  1
# 7396098   af1ae35f96a1e23fd342cd43a4685601f8bc27af  SOUMESW12A8C140A28  2
# 44047297  7d6711d7c9902d2d379d6c762810bdc400039233  SOKRAMY12A8C140804  1
# 2013062   9035632d0d57922d909dfaee74abf89e06f5f00e  SOLTCOF12AB017FDA3  3
# 35189762  4a483f571410a844d3bccc8432c0dd48053aff7a  SOVJHCB12A8AE4636E  5
# 9584591   436516e3c41fdf66b304bb41158fa92e7b18b319  SOEGIYH12A6D4FC0E3  7

# %%
listen_count[2] = 1
