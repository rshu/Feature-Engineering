# %%
import pandas as pd
import json

# %%
biz_file = open('./dataset/yelp_academic_dataset_business.json')
biz_df = pd.DataFrame([json.loads(x) for x in biz_file.readlines()])
biz_file.close()

# %%
biz_df.sample(n=10, random_state=1)
# Out:
#                   business_id  \
# 7289   lfjzCAxtBzZiB9cxpn3BqQ
# 8157   IBP22oiElBtqEblBvwq28g
# 551    8r4SKAKp_ugLrmhrxDBBtg
# 12813  eb-d7bMXnzO8DGWJ5x552g
# 10615  ZCMEPB97LvC2jV7hIQRnDw
# 5765   EuNV8_SReV_3KeET2Ums6A
# 15129  9k5OdmvTCLvYH_u8RQ3Duw
# 6857   heyprN6HwLYVWINXd2z3OQ
# 11883  -AcBphGFzYILy1XhnAwQTw
# 11044  plyGN0GvDBDBV-jFOWnSqg
#
#                                             full_address  \
# 7289           2475 W Queen Creek Rd\nChandler, AZ 85248
# 8157   10030 W McDowell Road\nSuite 150\nAvondale, AZ...
# 551                    1006 E Warner Rd\nTempe, AZ 85284
# 12813                  1920 W Bell Rd\nPhoenix, AZ 85023
# 10615                  1605 N 7th Ave\nPhoenix, AZ 85007
# 5765         3530 N Goldwater Blvd\nScottsdale, AZ 85251
# 15129                    222 N Ash St\nGilbert, AZ 85234
# 6857                19420 N 59th Ave\nGlendale, AZ 85308
# 11883            510 S 52nd St\nSte 105\nTempe, AZ 85281
# 11044             3446 W Camelback Rd\nPhoenix, AZ 85017
#
#                                                    hours   open  \
# 7289   {'Monday': {'close': '22:00', 'open': '11:00'}...   True
# 8157                                                  {}   True
# 551    {'Monday': {'close': '22:00', 'open': '11:00'}...  False
# 12813                                                 {}   True
# 10615  {'Tuesday': {'close': '18:00', 'open': '11:00'...   True
# 5765                                                  {}   True
# 15129  {'Saturday': {'close': '12:00', 'open': '08:00'}}   True
# 6857   {'Monday': {'close': '14:30', 'open': '06:30'}...   True
# 11883  {'Monday': {'close': '16:00', 'open': '09:00'}...   True
# 11044                                                 {}   True
#
#                                               categories        city  \
# 7289                           [Sushi Bars, Restaurants]    Chandler
# 8157   [Videos & Video Game Rental, Books, Mags, Musi...    Avondale
# 551                                 [Pizza, Restaurants]       Tempe
# 12813          [Breakfast & Brunch, Diners, Restaurants]     Phoenix
# 10615  [Fashion, Shopping, Beauty & Spas, Accessories...     Phoenix
# 5765      [Fast Food, Sushi Bars, Japanese, Restaurants]  Scottsdale
# 15129                             [Food, Farmers Market]     Gilbert
# 6857   [Breakfast & Brunch, American (New), Restaurants]    Glendale
# 11883  [Party Supplies, Event Planning & Services, Pa...       Tempe
# 11044            [Local Services, Child Care & Day Care]     Phoenix
#
#        review_count                              name neighborhoods  \
# 7289            116                    The Sushi Room            []
# 8157              3                          Gamestop            []
# 551              13                     Barro's Pizza            []
# 12813             8                   IHOP Restaurant            []
# 10615            14                    Boutique Solie            []
# 5765             37                     Tokyo Express            []
# 15129            43            Gilbert Farmers Market            []
# 6857             41                     Biscuits Café            []
# 11883             5  Affordable Party & Event Rentals            []
# 11044             3             Children's Campus Too            []
#
#         longitude state  stars   latitude  \
# 7289  -111.883025    AZ    3.5  33.261457
# 8157  -112.345359    AZ    4.5  33.430535
# 551   -111.927079    AZ    4.0  33.335018
# 12813 -112.100947    AZ    3.0  33.640570
# 10615 -112.082627    AZ    5.0  33.466025
# 5765  -111.927107    AZ    3.0  33.489246
# 15129 -111.791124    AZ    4.5  33.354862
# 6857  -112.187000    AZ    3.0  33.661670
# 11883 -111.924088    AZ    5.0  33.424281
# 11044 -112.132900    AZ    1.0  33.510442
#
#                                               attributes      type
# 7289   {'Take-out': True, 'Wi-Fi': 'no', 'Good For': ...  business
# 8157   {'Parking': {'garage': False, 'street': False,...  business
# 551    {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 12813  {'Noise Level': 'quiet', 'Parking': {'garage':...  business
# 10615  {'Price Range': 2, 'Dogs Allowed': True, 'Park...  business
# 5765   {'Take-out': True, 'Drive-Thru': True, 'Good F...  business
# 15129  {'Parking': {'garage': False, 'street': True, ...  business
# 6857   {'Take-out': True, 'Good For': {'dessert': Fal...  business
# 11883                     {'Accepts Credit Cards': True}  business
# 11044                     {'Accepts Credit Cards': True}  business

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('whitegrid')
fig, ax = plt.subplots()
biz_df['review_count'].hist(ax=ax, bins=100)
ax.set_yscale('log')
ax.tick_params(labelsize=14)
ax.set_xlabel('Review Count', fontsize=14)
ax.set_ylabel('Occurrence', fontsize=14)
# Out:
# Text(0, 0.5, 'Occurrence')
